# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_excel("/Users/manvithaponnapati/Documents/openag-basil-viability-experiment-foodserver-2/META_BV_FS2.xlsx")

# %%
df
# Out:
#      plant  bay res_design   crop container
# 0      101  201   75_liter  basil       FS2
# 1      102  201   75_liter  basil       FS2
# 2      103  201   75_liter  basil       FS2
# 3      104  201   75_liter  basil       FS2
# 4      105  201   75_liter  basil       FS2
# 5      106  201   75_liter  basil       FS2
# 6      107  201   75_liter  basil       FS2
# 7      108  201   75_liter  basil       FS2
# 8      109  201   75_liter  basil       FS2
# 9      110  201   75_liter  basil       FS2
# 10     111  201   75_liter  basil       FS2
# 11     112  201   75_liter  basil       FS2
# 12     113  201   75_liter  basil       FS2
# 13     114  201   75_liter  basil       FS2
# 14     115  201   75_liter  basil       FS2
# 15     116  201   75_liter  basil       FS2
# 16     117  201   75_liter  basil       FS2
# 17     118  201   75_liter  basil       FS2
# 18     201  202  150_liter  basil       FS2
# 19     202  202  150_liter  basil       FS2
# ...

# %%
import time
# "%Y%m%d %H:%M:%S"
def convert_time_to_str(x):
    return str(x)

# %%
bay_json = {}
for bay_id in bay_ids:
    bay_json[bay_id] = {}
    sub_df = df.loc[df['bay'] == bay_id]
    bay_json[bay_id]["date_times"] = sub_df["date_times_str"].tolist()
    bay_json[bay_id]["temp_c"] = sub_df["temp_c"].tolist()
    bay_json[bay_id]["relative_humidity_%"] = sub_df["relative_humidity_%"].tolist()
    bay_json[bay_id]["dewpoint"] = sub_df["dewpoint"].tolist()

# %%
giving lectures in a class; employing students as interns; guiding teams of
students performing practical classroom projects; assisting a student or faculty
member with a research project;
•
holding office hours to mentor students, faculty, alumni or VDC startups whO are starting businesses or studying entrepreneurship; 
•
serving as a business development ambassador and making connections
between the students, faculty, alumni or the VDC and the innovation
community and investors;
•
pursuing professional development activities and enhancing your own
entrepreneurial training and skills in the establishment of your business
venture by scheduling regular mentoring appointments with one of the VDC’s
Entrepreneurs-in-Residence
# Out:
#        container   crop  rep  bay placement      date      time   temp_c  \
# 0            FS2  basil  1.0  207    bottom  20180911  14:10:00  24.6006
# 1            FS2  basil  1.0  207    bottom  20180911  14:20:00  25.0082
# 2            FS2  basil  1.0  207    bottom  20180911  14:30:00  25.2441
# 3            FS2  basil  1.0  207    bottom  20180911  14:40:00  25.5444
# 4            FS2  basil  1.0  207    bottom  20180911  14:50:00  25.5551
# 5            FS2  basil  1.0  207    bottom  20180911  15:00:00  25.4479
# 6            FS2  basil  1.0  207    bottom  20180911  15:10:00  25.2870
# 7            FS2  basil  1.0  207    bottom  20180911  15:20:00  25.1798
# 8            FS2  basil  1.0  207    bottom  20180911  15:30:00  25.1798
# 9            FS2  basil  1.0  207    bottom  20180911  15:40:00  25.2227
# 10           FS2  basil  1.0  207    bottom  20180911  15:50:00  25.0832
# 11           FS2  basil  1.0  207    bottom  20180911  16:00:00  24.9545
# ...
